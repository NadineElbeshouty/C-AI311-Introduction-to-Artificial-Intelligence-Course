# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#creating a dataframe
df=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
df.head(5)
# Out:
#           A         B         C         D
# 0  0.161694  0.162654  0.378401  0.907890
# 1  0.850303  0.821692  0.598508  0.095757
# 2  0.748636  0.951701  0.765587  0.112452
# 3  0.127003  0.185537  0.615818  0.182229
# 4  0.172686  0.563416  0.108157  0.136588

# %%
#creating a dataframe with dictionary
df2 = pd.DataFrame({'A' : [10,20],'B' : [20,100],'C' : [30,40],'D' : [40,50]})
df2
# Out:
#     A    B   C   D
# 0  10   20  30  40
# 1  20  100  40  50

# %%
#looking at the variable types
df2.dtypes
# Out:
# A    int64
# B    int64
# C    int64
# D    int64
# dtype: object

# %%
#looking at the top few values, default 5
df.head()
# Out:
#           A         B         C         D
# 0  0.161694  0.162654  0.378401  0.907890
# 1  0.850303  0.821692  0.598508  0.095757
# 2  0.748636  0.951701  0.765587  0.112452
# 3  0.127003  0.185537  0.615818  0.182229
# 4  0.172686  0.563416  0.108157  0.136588

# %%
#looking at the last few values
df.tail()
# Out:
#           A         B         C         D
# 5  0.613800  0.712301  0.807522  0.323784
# 6  0.676467  0.835518  0.772403  0.536492
# 7  0.639357  0.839809  0.453456  0.823438
# 8  0.235693  0.873192  0.581841  0.168070
# 9  0.738122  0.866725  0.074416  0.955707

# %%
#to get the indexes
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#to get the column names
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
#to get the values
df.values
# Out:
# array([[0.16169354, 0.16265378, 0.37840146, 0.90789036],
#        [0.85030276, 0.8216922 , 0.5985084 , 0.09575658],
#        [0.74863628, 0.95170103, 0.76558745, 0.11245183],
#        [0.12700311, 0.18553672, 0.61581802, 0.18222937],
#        [0.17268638, 0.56341569, 0.10815701, 0.13658812],
#        [0.61379952, 0.71230106, 0.80752185, 0.32378444],
#        [0.67646664, 0.8355176 , 0.77240313, 0.53649187],
#        [0.63935701, 0.83980888, 0.45345619, 0.82343775],
#        [0.2356933 , 0.87319212, 0.58184062, 0.16807015],
#        [0.73812188, 0.86672512, 0.07441572, 0.95570701]])

# %%
#to get quick statistics about the data
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.496376   0.681254   0.515611   0.424241
# std     0.285810   0.287242   0.262108   0.351264
# min     0.127003   0.162654   0.074416   0.095757
# 25%     0.188438   0.600637   0.397165   0.144459
# 50%     0.626578   0.828605   0.590175   0.253007
# 75%     0.722708   0.859996   0.728145   0.751701
# max     0.850303   0.951701   0.807522   0.955707

# %%
# for sorting the index
df.sort_index(axis=0, ascending=False)
# Out:
#           A         B         C         D
# 9  0.738122  0.866725  0.074416  0.955707
# 8  0.235693  0.873192  0.581841  0.168070
# 7  0.639357  0.839809  0.453456  0.823438
# 6  0.676467  0.835518  0.772403  0.536492
# 5  0.613800  0.712301  0.807522  0.323784
# 4  0.172686  0.563416  0.108157  0.136588
# 3  0.127003  0.185537  0.615818  0.182229
# 2  0.748636  0.951701  0.765587  0.112452
# 1  0.850303  0.821692  0.598508  0.095757
# 0  0.161694  0.162654  0.378401  0.907890

# %%
#for sorting by a column
df.sort_values(by='A')
# Out:
#           A         B         C         D
# 3  0.127003  0.185537  0.615818  0.182229
# 0  0.161694  0.162654  0.378401  0.907890
# 4  0.172686  0.563416  0.108157  0.136588
# 8  0.235693  0.873192  0.581841  0.168070
# 5  0.613800  0.712301  0.807522  0.323784
# 7  0.639357  0.839809  0.453456  0.823438
# 6  0.676467  0.835518  0.772403  0.536492
# 9  0.738122  0.866725  0.074416  0.955707
# 2  0.748636  0.951701  0.765587  0.112452
# 1  0.850303  0.821692  0.598508  0.095757

# %% [markdown]
# # Selecting Values

# %%
# selecting columns
df['A']
# Out:
# 0    0.161694
# 1    0.850303
# 2    0.748636
# 3    0.127003
# 4    0.172686
# 5    0.613800
# 6    0.676467
# 7    0.639357
# 8    0.235693
# 9    0.738122
# Name: A, dtype: float64

# %%
#selecting range of rows
df[0:2]
# Out:
#           A         B         C         D
# 0  0.161694  0.162654  0.378401  0.907890
# 1  0.850303  0.821692  0.598508  0.095757

# %%
#selecting a particular row
df.loc[0]
# Out:
# A    0.161694
# B    0.162654
# C    0.378401
# D    0.907890
# Name: 0, dtype: float64

# %%
#selecting a row and column
df.loc[0,['A']]
# Out:
# A    0.161694
# Name: 0, dtype: float64

# %%
df.loc[:,['A']]
# Out:
#           A
# 0  0.161694
# 1  0.850303
# 2  0.748636
# 3  0.127003
# 4  0.172686
# 5  0.613800
# 6  0.676467
# 7  0.639357
# 8  0.235693
# 9  0.738122

# %%
#using at instead for faster access , can't be used for a range
df.at[0,'A']
# Out:
# 0.1616935438107674

# %%
#selecting by posion
df.iloc[0]
# Out:
# A    0.161694
# B    0.162654
# C    0.378401
# D    0.907890
# Name: 0, dtype: float64

# %%
#selecting by condition
df[df.A>0]
# Out:
#           A         B         C         D
# 0  0.161694  0.162654  0.378401  0.907890
# 1  0.850303  0.821692  0.598508  0.095757
# 2  0.748636  0.951701  0.765587  0.112452
# 3  0.127003  0.185537  0.615818  0.182229
# 4  0.172686  0.563416  0.108157  0.136588
# 5  0.613800  0.712301  0.807522  0.323784
# 6  0.676467  0.835518  0.772403  0.536492
# 7  0.639357  0.839809  0.453456  0.823438
# 8  0.235693  0.873192  0.581841  0.168070
# 9  0.738122  0.866725  0.074416  0.955707

# %% [markdown]
# # Missing Data

# %%
df2=df[df<.5]
df2
# Out:
#           A         B         C         D
# 0  0.161694  0.162654  0.378401       NaN
# 1       NaN       NaN       NaN  0.095757
# 2       NaN       NaN       NaN  0.112452
# 3  0.127003  0.185537       NaN  0.182229
# 4  0.172686       NaN  0.108157  0.136588
# 5       NaN       NaN       NaN  0.323784
# 6       NaN       NaN       NaN       NaN
# 7       NaN       NaN  0.453456       NaN
# 8  0.235693       NaN       NaN  0.168070
# 9       NaN       NaN  0.074416       NaN

# %%
#drop all rows which have NaN
df2.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
#replace NaN with other values
df2.fillna(value=1)

# %% [markdown]
# # Statistical Operations

# %%
# taking mean
df.mean()
# Out:
# A    0.496376
# B    0.681254
# C    0.515611
# D    0.424241
# dtype: float64

# %%
# mean in other axis
df.mean(1)
# Out:
# 0    0.402660
# 1    0.591565
# 2    0.644594
# 3    0.277647
# 4    0.245212
# 5    0.614352
# 6    0.705220
# 7    0.689015
# 8    0.464699
# 9    0.658742
# dtype: float64
